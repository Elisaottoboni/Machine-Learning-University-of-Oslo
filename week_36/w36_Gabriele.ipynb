# %% [markdown]
# <!-- HTML file automatically generated from DocOnce source (https://github.com/doconce/doconce/)
# doconce format html exercisesweek36.do.txt  -->
# <!-- dom:TITLE: Exercises week 36 -->

# %% [markdown]
# # Exercises week 36
# **September 2-6, 2024**
#
# Date: **Deadline is Friday September 6 at midnight**

# %% [markdown]
# ## Overarching aims of the exercises this week
#
# This set of exercises form an important part of the first project. The
# analytical exercises deal with the material covered last week on the
# mathematical interpretations of ordinary least squares and of Ridge
# regression. The numerical exercises can be seen as a continuation of
# exercise 3 from week 35, with the inclusion of Ridge regression. This
# material enters also the discussions of the first project.

# %% [markdown]
# ## Exercise 1: Analytical exercises
#
# The aim here is to derive the expression for the optimal parameters
# using Ridge regression. Furthermore, using the singular value
# decomposition, we will analyze the difference between the ordinary
# least squares approach and Ridge regression.
#
# The expression for the standard Mean Squared Error (MSE) which we used to define our cost function and the equations for the ordinary least squares (OLS) method, was given by the
# optimization problem

# %% [markdown]
# $$
# {\displaystyle \min_{\boldsymbol{\beta}\in {\mathbb{R}}^{p}}}\frac{1}{n}\left\{\left(\boldsymbol{y}-\boldsymbol{X}\boldsymbol{\beta}\right)^T\left(\boldsymbol{y}-\boldsymbol{X}\boldsymbol{\beta}\right)\right\}.
# $$

# %% [markdown]
# which we can also write as

# %% [markdown]
# $$
# {\displaystyle \min_{\boldsymbol{\beta}\in
# {\mathbb{R}}^{p}}}\frac{1}{n}\sum_{i=0}^{n-1}\left(y_i-\tilde{y}_i\right)^2=\frac{1}{n}\vert\vert \boldsymbol{y}-\boldsymbol{X}\boldsymbol{\beta}\vert\vert_2^2,
# $$

# %% [markdown]
# where we have used the definition of  a norm-2 vector, that is

# %% [markdown]
# $$
# \vert\vert \boldsymbol{x}\vert\vert_2 = \sqrt{\sum_i x_i^2}.
# $$

# %% [markdown]
# By minimizing the above equation with respect to the parameters
# $\boldsymbol{\beta}$ we could then obtain an analytical expression for the
# parameters $\boldsymbol{\beta}$.
#
# We can add a regularization parameter $\lambda$ by
# defining a new cost function to be optimized, that is

# %% [markdown]
# $$
# {\displaystyle \min_{\boldsymbol{\beta}\in
# {\mathbb{R}}^{p}}}\frac{1}{n}\vert\vert \boldsymbol{y}-\boldsymbol{X}\boldsymbol{\beta}\vert\vert_2^2+\lambda\vert\vert \boldsymbol{\beta}\vert\vert_2^2
# $$

# %% [markdown]
# which leads to the Ridge regression minimization problem. One can require as part of the optimization problem
# that $\vert\vert \boldsymbol{\beta}\vert\vert_2^2\le t$, where $t$ is
# a finite number larger than zero. We will not implement that here.

# %% [markdown]
# ### a) Expression for Ridge regression
#
# Show that the optimal parameters

# %% [markdown]
# $$
# \hat{\boldsymbol{\beta}}_{\mathrm{Ridge}} = \left(\boldsymbol{X}^T\boldsymbol{X}+\lambda\boldsymbol{I}\right)^{-1}\boldsymbol{X}^T\boldsymbol{y},
# $$

# %% [markdown]
# with $\boldsymbol{I}$ being a $p\times p$ identity matrix.
#
# The ordinary least squares result is

# %% [markdown]
# $$
# \hat{\boldsymbol{\beta}}_{\mathrm{OLS}} = \left(\boldsymbol{X}^T\boldsymbol{X}\right)^{-1}\boldsymbol{X}^T\boldsymbol{y},
# $$

# %% [markdown]
# ![Taccuino senza nome-1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### b) The singular value decomposition
#
# Here we will use the singular value decomposition of an $n\times p$ matrix $\boldsymbol{X}$ (our design matrix)

# %% [markdown]
# $$
# \boldsymbol{X}=\boldsymbol{U}\boldsymbol{\Sigma}\boldsymbol{V}^T,
# $$

# %% [markdown]
# to study properties of Ridge regression and ordinary least squares regression.
# Here $\boldsymbol{U}$ and $\boldsymbol{V}$ are orthogonal matrices of dimensions
# $n\times n$ and $p\times p$, respectively, and $\boldsymbol{\Sigma}$ is an
# $n\times p$ matrix which contains the singular values only. This material was discussed during the lectures of week 35.
#
# Show that you can write the
# OLS solutions in terms of the eigenvectors (the columns) of the orthogonal matrix  $\boldsymbol{U}$ as

# %% [markdown]
# $$
# \tilde{\boldsymbol{y}}_{\mathrm{OLS}}=\boldsymbol{X}\boldsymbol{\beta}  = \sum_{j=0}^{p-1}\boldsymbol{u}_j\boldsymbol{u}_j^T\boldsymbol{y}.
# $$

# %% [markdown]
# For Ridge regression, show that the corresponding equation is

# %% [markdown]
# $$
# \tilde{\boldsymbol{y}}_{\mathrm{Ridge}}=\boldsymbol{X}\boldsymbol{\beta}_{\mathrm{Ridge}} = \boldsymbol{U\Sigma V^T}\left(\boldsymbol{V}\boldsymbol{\Sigma}^2\boldsymbol{V}^T+\lambda\boldsymbol{I} \right)^{-1}(\boldsymbol{U\Sigma V^T})^T\boldsymbol{y}=\sum_{j=0}^{p-1}\boldsymbol{u}_j\boldsymbol{u}_j^T\frac{\sigma_j^2}{\sigma_j^2+\lambda}\boldsymbol{y},
# $$

# %% [markdown]
# with the vectors $\boldsymbol{u}_j$ being the columns of $\boldsymbol{U}$ from the SVD of the matrix $\boldsymbol{X}$.
#
# Give an interpretation of the results.  [Section 3.4 of Hastie et al's textbook gives a good discussion of the above results](https://link.springer.com/book/10.1007/978-0-387-84858-7).

# %% [markdown]
# ![Taccuino senza nome-2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Exercise 2: Adding Ridge Regression
#
# This exercise is a continuation of exercise 3 from week 35, see <https://compphysics.github.io/MachineLearning/doc/LectureNotes/_build/html/exercisesweek35.html>. We will use the same function to
# generate our data set, still staying with a simple function $y(x)$
# which we want to fit using linear regression, but now extending the
# analysis to include the Ridge regression method.
#
# In this exercise you need to include the same elements from last week, that is
# 1. scale your data by subtracting the mean value from each column in the design matrix.
#
# 2. perform a split of the data in a training set and a test set.
#
# The addition to the analysis this time is the introduction of the hyperparameter $\lambda$ when introducing Ridge regression.
#
# Extend the code from exercise 3 from [week 35](https://compphysics.github.io/MachineLearning/doc/LectureNotes/_build/html/exercisesweek35.html) to include Ridge regression with the hyperparameter $\lambda$. The optimal parameters $\hat{\beta}$ for Ridge regression can be obtained by matrix inversion in a similar way as done for ordinary least squares. You need to add to your code the following equations

# %% [markdown]
# $$
# \hat{\boldsymbol{\beta}}_{\mathrm{Ridge}} = \left(\boldsymbol{X}^T\boldsymbol{X}+\lambda\boldsymbol{I}\right)^{-1}\boldsymbol{X}^T\boldsymbol{y}.
# $$

# %% [markdown]
# The ordinary least squares result you encoded last week is given by

# %% [markdown]
# $$
# \hat{\boldsymbol{\beta}}_{\mathrm{OLS}} = \left(\boldsymbol{X}^T\boldsymbol{X}\right)^{-1}\boldsymbol{X}^T\boldsymbol{y},
# $$

# %% [markdown]
# Use these results to compute the mean squared error for ordinary least
# squares and Ridge regression first for a polynomial of degree five
# with $n=100$ data points and five selected values of
# $\lambda=[0.0001,0.001, 0.01,0.1,1.0]$. Compute thereafter the mean
# squared error for the same values of $\lambda$ for polynomials of degree ten
# and $15$. Discuss your results for the training MSE and test MSE with
# Ridge regression and ordinary least squares.

# %%
import numpy as np

np.random.seed(1001021)
n = 100
x = np.linspace(-3, 3, n).reshape(-1, 1)
y = np.exp(-x**2) + 1.5 * np.exp(-(x-2)**2)+ np.random.normal(0, 0.1, x.shape)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.scatter(x,y, color='blue')
plt.show()

# %%
np.random.seed(1001021)
n = 100
x = np.linspace(-3, 3, n)
y = np.exp(-x**2) + 1.5 * np.exp(-(x-2)**2)+ np.random.normal(0, 0.1, x.shape)

# design matrix
# X = np.hstack([x**i for i in range(6)])
# X = X[:, ~(np.all(X == 1, axis=0))]

Maxpolydegree = 6
X = np.zeros((n,Maxpolydegree))
#We include explicitely the intercept column
for degree in range(Maxpolydegree):
    X[:,degree] = x**degree

print(X)
# Out:
# [[ 1.00000000e+00 -3.00000000e+00  9.00000000e+00 -2.70000000e+01
#    8.10000000e+01 -2.43000000e+02]
#  [ 1.00000000e+00 -2.93939394e+00  8.64003673e+00 -2.53964716e+01
#    7.46502347e+01 -2.19426447e+02]
#  [ 1.00000000e+00 -2.87878788e+00  8.28741965e+00 -2.38577232e+01
#    6.86813245e+01 -1.97718964e+02]
#  [ 1.00000000e+00 -2.81818182e+00  7.94214876e+00 -2.23824192e+01
#    6.30777269e+01 -1.77764503e+02]
#  [ 1.00000000e+00 -2.75757576e+00  7.60422406e+00 -2.09692239e+01
#    5.78242235e+01 -1.59454677e+02]
#  [ 1.00000000e+00 -2.69696970e+00  7.27364555e+00 -1.96168016e+01
#    5.29059195e+01 -1.42685662e+02]
#  [ 1.00000000e+00 -2.63636364e+00  6.95041322e+00 -1.83238167e+01
#    4.83082440e+01 -1.27358098e+02]
#  [ 1.00000000e+00 -2.57575758e+00  6.63452709e+00 -1.70889334e+01
#    4.40169497e+01 -1.13376992e+02]
#  [ 1.00000000e+00 -2.51515152e+00  6.32598714e+00 -1.59108162e+01
#    4.00181133e+01 -1.00651618e+02]
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Evaluate the mean
X_train_mean = np.mean(X_train, axis=0)

# Center by removing the mean from each feature
X_train_scaled = X_train - X_train_mean
X_test_scaled = X_test - X_train_mean

y_scaler = np.mean(y_train)
y_train_scaled = y_train - y_scaler

print(X_train_mean)
# Out:
# [1.00000000e+00 1.51515152e-02 3.11790634e+00 3.30884604e-02
#  1.72926778e+01 1.14362072e+00]

# %%
from sklearn.preprocessing import StandardScaler

scaler_X = StandardScaler()

X_train_scaled = scaler_X.fit_transform(X_train)
X_test_scaled = scaler_X.transform(X_test)
print(scaler_X.mean_)

scaler_y = StandardScaler()
y_train_scaled = scaler_y.fit_transform(y_train.reshape(-1, 1)).ravel()
y_test_scaled = scaler_y.transform(y_test.reshape(-1, 1)).ravel()
# Out:
# [1.00000000e+00 1.51515152e-02 3.11790634e+00 3.30884604e-02
#  1.72926778e+01 1.14362072e+00]

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Plot before scaling
n_features = X_train.shape[1]
plt.figure(figsize=(16, 6))

for i in range(n_features):
    plt.subplot(2, n_features, i + 1)
    plt.scatter(X_train[:, i], y_train, alpha=0.5)
    plt.title(f'Feature {i+1} before scaling')
    plt.xlabel(f'Feature {i+1}')
    plt.ylabel('y')

# Plot after scaling
for i in range(n_features):
    plt.subplot(2, n_features, n_features + i + 1)
    plt.scatter(X_train_scaled[:, i], y_train, alpha=0.5, color='orange')
    plt.title(f'Feature {i+1} after scaling')
    plt.xlabel(f'Feature {i+1}')
    plt.ylabel('y')

plt.tight_layout()
plt.show()

# %%
# difference
differences = X_train_scaled - X_train

# plotting
plt.figure(figsize=(12, 6))
plt.plot(differences)
plt.title('Difference between original data and scaled data')
plt.xlabel('Data')
plt.ylabel('Difference')
plt.show()

# %% [markdown]
# ### Differences in using my own code and Sklearn

# %%
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_absolute_error, r2_score

p = 6
I = np.eye(p,p)

lambdas = [0.0001,0.001, 0.01,0.1,1.0]
MSERidge1 = []
MSERidgeSklearn1  = []
ypredictRidge1 = []
ypredictRidge_sklearn1 = []

def MSE(y_data,y_model):
    n = np.size(y_model)
    return np.sum((y_data-y_model)**2)/n
 

for i in range(len(lambdas)):
   lmb = lambdas[i]
   RidgeBeta = np.linalg.pinv(X_train_scaled.T @ X_train_scaled + lmb * I) @ X_train_scaled.T @ y_train_scaled
   ytildeRidge = X_train_scaled @ RidgeBeta
   ypredictRidge = X_test_scaled @ RidgeBeta
   MSERidge = mean_absolute_error(y_test, ypredictRidge)
   MSERidge1.append(MSERidge)
   ypredictRidge1.append(ypredictRidge)
   R2Ridge = r2_score(y_test, ypredictRidge)
   
   
   RegRidge = Ridge(lmb, fit_intercept=False)
   RegRidge.fit(X_train_scaled, y_train_scaled)
   ytildeRidge_sklearn = RegRidge.predict(X_train_scaled)
   ypredictRidge_sklearn = RegRidge.predict(X_test_scaled)
   MSERidgeSklearn = mean_absolute_error(y_test, ypredictRidge_sklearn)
   MSERidgeSklearn1.append(MSERidgeSklearn)
   ypredictRidge_sklearn1.append(ypredictRidge_sklearn)
   R2Ridge_Sklearn = r2_score(y_test, ypredictRidge)

# %%
ypredictRidge1[0] - ypredictRidge_sklearn1[0]
# Out:
# array([ 6.88338275e-15,  3.49720253e-15, -5.99520433e-15, -7.77156117e-15,
#         5.88418203e-15,  2.99760217e-15, -2.66453526e-15,  2.22044605e-15,
#        -3.33066907e-15,  3.55271368e-15,  7.10542736e-15,  6.16173779e-15,
#        -3.99680289e-15,  8.88178420e-16,  1.13797860e-15, -2.44249065e-15,
#         5.99520433e-15,  6.77236045e-15, -3.10862447e-15,  6.21724894e-15])

# %% [markdown]
# ### Ridge using 5 degree Polynomial

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn.preprocessing import StandardScaler

def MSE(y_data,y_model):
    n = np.size(y_model)
    return np.sum((y_data-y_model)**2)/n
np.random.seed(1001021)

n = 100
x = np.linspace(-3, 3, n)
y = np.exp(-x**2) + 1.5 * np.exp(-(x-2)**2)+ np.random.normal(0, 0.1, x.shape)

Maxpolydegree = 6
X = np.zeros((n,Maxpolydegree-1))

for degree in range(1,Maxpolydegree):
    X[:,degree-1] = x**(degree)

# Splitting
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Scaling
X_train_mean = np.mean(X_train,axis=0)
X_train_scaled = X_train - X_train_mean 
X_test_scaled = X_test - X_train_mean
y_scaler = np.mean(y_train)           
y_train_scaled = y_train - y_scaler   

p = Maxpolydegree-1
I = np.eye(p,p)
# Initializing
MSEOwnRidgePredict = np.zeros(len(lambdas))
MSERidgePredict = np.zeros(len(lambdas))
MSERidgePredictTrain = np.zeros(len(lambdas))



lambdas = [0.0001,0.001, 0.01,0.1,1.0]

mse_train_values = []
mse_test_values = []
R2RidgePred = []
R2RidgeTrain = []

for i in range(len(lambdas)):
    lmb = lambdas[i]
    OwnRidgeBeta = np.linalg.pinv(X_train_scaled.T @ X_train_scaled+lmb*I) @ X_train_scaled.T @ (y_train_scaled)
    intercept_ = y_scaler - X_train_mean@OwnRidgeBeta #The intercept can be shifted so the model can predict on uncentered data
    #Add intercept to prediction
    ypredictOwnRidge = X_test_scaled @ OwnRidgeBeta + y_scaler
    MSEOwnRidgePredict[i] = MSE(y_test,ypredictOwnRidge)
    R2Ridge = r2_score(y_test, ypredictOwnRidge)
    
    RegRidge = linear_model.Ridge(lmb)
    RegRidge.fit(X_train,y_train)
    ypredictRidge = RegRidge.predict(X_test)
    ytrainpredictRidge = RegRidge.predict(X_train)
    MSERidgePredict[i] = MSE(y_test,ypredictRidge)
    R2Ridge_Sklearn = r2_score(y_test, ypredictRidge)
    R2Ridge_Sklearn_train = r2_score(y_train, ytrainpredictRidge)
    mse_test_values.append(MSERidgePredict)
    R2RidgePred.append(R2Ridge_Sklearn)
    R2RidgeTrain.append(R2Ridge_Sklearn_train)
   
    ypredictRidgeTrain = RegRidge.predict(X_train)
    MSERidgePredictTrain[i] = MSE(y_train,ypredictRidgeTrain) 
    mse_train_values.append(MSERidgePredictTrain)

    
    # Outputs
    print(f'Betas (own code) with lambda:{lmb}')
    print(OwnRidgeBeta)
    print(f'Betas (Sklearn) with lambda:{lmb}')
    print(RegRidge.coef_)
    print(f'Intercept (own code) with lambda:{lmb}')
    print(intercept_)
    print(f'Intercept (Sklearn) with lambda:{lmb}')
    print(RegRidge.intercept_)
    print(f'MSE (own code) with lambda:{lmb}')
    print(MSEOwnRidgePredict[i])
    print(f'MSE (Sklearn) with lambda:{lmb}')
    print(MSERidgePredict[i])
    print(f'R2 (own code) with lambda:{lmb}')
    print(R2Ridge)
    print(f'R2 (Sklearn) with lambda:{lmb}')
    print(R2Ridge_Sklearn)
    
plt.figure(figsize=(10, 6))
plt.plot(np.log10(lambdas), MSEOwnRidgePredict, 'b--', label = 'MSE own Ridge Test')
plt.plot(np.log10(lambdas), MSERidgePredict, 'g--', label = 'MSE SL Ridge Test')
plt.xlabel('log10(lambda)')
plt.ylabel('MSE')
plt.legend()
plt.show()
# Out:
# Betas (own code) with lambda:0.0001
# [ 0.27211035 -0.01154863  0.04188286 -0.00480723 -0.00726688]
# Betas (Sklearn) with lambda:0.0001
# [ 0.27211035 -0.01154863  0.04188286 -0.00480723 -0.00726688]
# Intercept (own code) with lambda:0.0001
# 0.8153177468345518
# Intercept (Sklearn) with lambda:0.0001
# 0.8153177468345543
# MSE (own code) with lambda:0.0001
# 0.026108356900521663
# MSE (Sklearn) with lambda:0.0001
# 0.026108356900520775
# R2 (own code) with lambda:0.0001
# 0.9058795682209885
# R2 (Sklearn) with lambda:0.0001
# 0.9058795682209917
# Betas (own code) with lambda:0.001
# [ 0.27209189 -0.01154868  0.04188998 -0.00480723 -0.00726748]
# Betas (Sklearn) with lambda:0.001
# [ 0.27209189 -0.01154868  0.04188998 -0.00480723 -0.00726748]
# Intercept (own code) with lambda:0.001
# 0.8153186408955022
# Intercept (Sklearn) with lambda:0.001
# 0.8153186408954969
# MSE (own code) with lambda:0.001
# 0.026109079328800078
# MSE (Sklearn) with lambda:0.001
# 0.026109079328799346
# ...

# %%
# - Both curves exhibit similar behavior, indicating comparable performance between 
#   the custom implementation and the external library's model.
# - The MSE remains relatively constant for smaller values of lambda (log10(lambda) between -4 and -1.5).
#   This suggests that the model isn't highly influenced by regularization in this range.
# - For log10(lambda) > -1, the MSE rises sharply, meaning that excessive regularization 
#   worsens the model's performance by overly shrinking the coefficients.

# %%
# Plotting
plt.figure(figsize=(10, 6))
plt.plot(range(1, Maxpolydegree), mse_train_values[4], label='Train MSE', marker='o')
plt.plot(range(1, Maxpolydegree), mse_test_values[4], label='Test MSE', marker='o')
plt.xlabel('Degree of Polynomial')
plt.ylabel('MSE')
plt.title('MSE for Train & Test Data vs. Polynomial Degree')
# plt.yscale('log')
plt.legend()
plt.show()

# Finding the optimal degree with the smallest test MSE
optimal_degree = np.argmin(mse_test_values) + 1
print(f'Optimal polynomial degree: {optimal_degree}')
# Out:
# Optimal polynomial degree: 1

# %%
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.preprocessing import PolynomialFeatures

# Perform Ordinary Least Squares (OLS) fitting
model = make_pipeline(PolynomialFeatures(degree=5), LinearRegression())
model.fit(X_train, y_train)

# Predict on training and test sets
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# Compute Mean Squared Error (MSE)
mse_train = mean_absolute_error(y_test, y_test_pred)
mse_test = mean_absolute_error(y_test, y_test_pred)

# %%
np.mean(R2RidgeTrain)
# Out:
# 0.9154343385227589

# %%
# OLS
print(f"MSE OLS (Train data): {mse_train:.4f}")
print(f"MSE OLS (Test data): {mse_test:.4f}")
print(f"R2 OLS (Train data): {r2_score(y_train, y_train_pred):.4f}")
print(f"R2 OLS (Test data): {r2_score(y_test, y_test_pred):.4f}")

# Ridge
print('')
print(f"MSE Ridge (Train data): {np.mean(mse_train_values[0]):.4f}")
print(f"MSE Ridge (Test data): {np.mean(mse_test_values[0]):.4f}")
print(f"R2 Ridge (Train data): {np.mean(R2RidgePred):.4f}")
print(f"R2 Ridge (Test data): {np.mean(R2RidgeTrain):.4f}")
# Out:
# MSE OLS (Train data): 0.0687
# MSE OLS (Test data): 0.0687
# R2 OLS (Train data): 0.9700
# R2 OLS (Test data): 0.9681
#
# MSE Ridge (Train data): 0.0208
# MSE Ridge (Test data): 0.0263
# R2 Ridge (Train data): 0.9052
# R2 Ridge (Test data): 0.9154

# %% [markdown]
# #### **Talking about the results**
#
# 1. OLS:
# The MSE is lower than the Ridge Regression one, this means more accurancy generally. In this case the MSE of train and test are equal, this maybe means that the OLS model fit well in both situations without evidents overfitting and underfitting. The R2 is pretty high in this model in both train and test.
#
# 2. Ridge: The MSE is lower than in the OLS, this means that the model has high capability in generalisation and hand well the data noise. The R2 is lower then OLS and maybe it explain less variance tha the other model but in this situation with a lower value for the MSE, the model should be less sensitive to overfitting and more robust
#
# 3. Final consideration
# The OLS model has a very high R2, but the MSE values suggest that it might be more exposed to overfitting, especially if the data contains multicollinearity or noise.
# In contrast, while Ridge regression has a slightly lower R2, its reduced MSE indicates that this model is more stable and less likely to overfit, making it more suitable for handling complex or multicollinear data.

# %% [markdown]
# ### Ridge using 10 degree Polynomial

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn.preprocessing import StandardScaler

def MSE(y_data,y_model):
    n = np.size(y_model)
    return np.sum((y_data-y_model)**2)/n
np.random.seed(1001021)

n = 100
x = np.linspace(-3, 3, n)
y = np.exp(-x**2) + 1.5 * np.exp(-(x-2)**2)+ np.random.normal(0, 0.1, x.shape)

Maxpolydegree = 11
X = np.zeros((n,Maxpolydegree-1))

for degree in range(1,Maxpolydegree):
    X[:,degree-1] = x**(degree)

# Splitting
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Scaling
X_train_mean = np.mean(X_train,axis=0)
X_train_scaled = X_train - X_train_mean 
X_test_scaled = X_test - X_train_mean
y_scaler = np.mean(y_train)           
y_train_scaled = y_train - y_scaler   

p = Maxpolydegree-1
I = np.eye(p,p)
# Initializing
MSEOwnRidgePredict = np.zeros(len(lambdas))
MSERidgePredict = np.zeros(len(lambdas))


lambdas = [0.0001,0.001, 0.01,0.1,1.0]


for i in range(len(lambdas)):
    lmb = lambdas[i]
    OwnRidgeBeta = np.linalg.pinv(X_train_scaled.T @ X_train_scaled+lmb*I) @ X_train_scaled.T @ (y_train_scaled)
    intercept_ = y_scaler - X_train_mean@OwnRidgeBeta #The intercept can be shifted so the model can predict on uncentered data
    #Add intercept to prediction
    ypredictOwnRidge = X_test_scaled @ OwnRidgeBeta + y_scaler
    MSEOwnRidgePredict[i] = MSE(y_test,ypredictOwnRidge)
    R2Ridge = r2_score(y_test, ypredictOwnRidge)
    
    RegRidge = linear_model.Ridge(lmb)
    RegRidge.fit(X_train,y_train)
    ypredictRidge = RegRidge.predict(X_test)
    MSERidgePredict[i] = MSE(y_test,ypredictRidge)
    R2Ridge_Sklearn = r2_score(y_test, ypredictRidge)

    
    # Outputs
    print(f'Betas (own code) with lambda:{lmb}')
    print(OwnRidgeBeta)
    print(f'Betas (Sklearn) with lambda:{lmb}')
    print(RegRidge.coef_)
    print(f'Intercept (own code) with lambda:{lmb}')
    print(intercept_)
    print(f'Intercept (Sklearn) with lambda:{lmb}')
    print(RegRidge.intercept_)
    print(f'MSE (own code) with lambda:{lmb}')
    print(MSEOwnRidgePredict[i])
    print(f'MSE (Sklearn) with lambda:{lmb}')
    print(MSERidgePredict[i])
    print(f'R2 (own code) with lambda:{lmb}')
    print(R2Ridge)
    print(f'R2 (Sklearn) with lambda:{lmb}')
    print(R2Ridge_Sklearn)
    
plt.figure(figsize=(10, 6))
plt.plot(np.log10(lambdas), MSEOwnRidgePredict, 'b--', label = 'MSE own Ridge Test')
plt.plot(np.log10(lambdas), MSERidgePredict, 'g--', label = 'MSE SL Ridge Test')
plt.xlabel('log10(lambda)')
plt.ylabel('MSE')
plt.legend()
plt.show()
# Out:
# Betas (own code) with lambda:0.0001
# [ 8.69892356e-02 -6.96503527e-01  2.96350081e-01  4.29526793e-01
#  -9.68365874e-02 -1.02644701e-01  1.16424597e-02  1.04057657e-02
#  -5.05811470e-04 -3.84879921e-04]
# Betas (Sklearn) with lambda:0.0001
# [ 8.69891948e-02 -6.96503514e-01  2.96350126e-01  4.29526782e-01
#  -9.68366032e-02 -1.02644698e-01  1.16424618e-02  1.04057652e-02
#  -5.05811572e-04 -3.84879902e-04]
# Intercept (own code) with lambda:0.0001
# 1.0033384559925989
# Intercept (Sklearn) with lambda:0.0001
# 1.0033384539965027
# MSE (own code) with lambda:0.0001
# 0.007153699690611975
# MSE (Sklearn) with lambda:0.0001
# 0.007153699543688667
# R2 (own code) with lambda:0.0001
# 0.9742109660035968
# R2 (Sklearn) with lambda:0.0001
# 0.9742109665332542
# Betas (own code) with lambda:0.001
# [ 8.70675742e-02 -6.95667907e-01  2.96214116e-01  4.28860663e-01
#  -9.67819642e-02 -1.02450294e-01  1.16344971e-02  1.03820663e-02
#  -5.05424634e-04 -3.83855386e-04]
# ...

# %% [markdown]
# ### Ridge using 15 degree Polynomial

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn.preprocessing import StandardScaler

def MSE(y_data,y_model):
    n = np.size(y_model)
    return np.sum((y_data-y_model)**2)/n
np.random.seed(1001021)

n = 100
x = np.linspace(-3, 3, n)
y = np.exp(-x**2) + 1.5 * np.exp(-(x-2)**2)+ np.random.normal(0, 0.1, x.shape)

Maxpolydegree = 16
X = np.zeros((n,Maxpolydegree-1))

for degree in range(1,Maxpolydegree):
    X[:,degree-1] = x**(degree)

# Splitting
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Scaling
X_train_mean = np.mean(X_train,axis=0)
X_train_scaled = X_train - X_train_mean 
X_test_scaled = X_test - X_train_mean
y_scaler = np.mean(y_train)           
y_train_scaled = y_train - y_scaler   

p = Maxpolydegree-1
I = np.eye(p,p)
# Initializing
MSEOwnRidgePredict = np.zeros(len(lambdas))
MSERidgePredict = np.zeros(len(lambdas))


lambdas = [0.0001,0.001, 0.01,0.1,1.0]


for i in range(len(lambdas)):
    lmb = lambdas[i]
    OwnRidgeBeta = np.linalg.pinv(X_train_scaled.T @ X_train_scaled+lmb*I) @ X_train_scaled.T @ (y_train_scaled)
    intercept_ = y_scaler - X_train_mean@OwnRidgeBeta #The intercept can be shifted so the model can predict on uncentered data
    #Add intercept to prediction
    ypredictOwnRidge = X_test_scaled @ OwnRidgeBeta + y_scaler
    MSEOwnRidgePredict[i] = MSE(y_test,ypredictOwnRidge)
    R2Ridge = r2_score(y_test, ypredictOwnRidge)
    
    RegRidge = linear_model.Ridge(lmb)
    RegRidge.fit(X_train,y_train)
    ypredictRidge = RegRidge.predict(X_test)
    MSERidgePredict[i] = MSE(y_test,ypredictRidge)
    R2Ridge_Sklearn = r2_score(y_test, ypredictRidge)

    
    # Outputs
    print(f'Betas (own code) with lambda:{lmb}')
    print(OwnRidgeBeta)
    print(f'Betas (Sklearn) with lambda:{lmb}')
    print(RegRidge.coef_)
    print(f'Intercept (own code) with lambda:{lmb}')
    print(intercept_)
    print(f'Intercept (Sklearn) with lambda:{lmb}')
    print(RegRidge.intercept_)
    print(f'MSE (own code) with lambda:{lmb}')
    print(MSEOwnRidgePredict[i])
    print(f'MSE (Sklearn) with lambda:{lmb}')
    print(MSERidgePredict[i])
    print(f'R2 (own code) with lambda:{lmb}')
    print(R2Ridge)
    print(f'R2 (Sklearn) with lambda:{lmb}')
    print(R2Ridge_Sklearn)
    
plt.figure(figsize=(10, 6))
plt.plot(np.log10(lambdas), MSEOwnRidgePredict, 'b--', label = 'MSE own Ridge Test')
plt.plot(np.log10(lambdas), MSERidgePredict, 'g--', label = 'MSE SL Ridge Test')
plt.xlabel('log10(lambda)')
plt.ylabel('MSE')
plt.legend()
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:200: LinAlgWarning: Ill-conditioned matrix (rcond=2.22249e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:200: LinAlgWarning: Ill-conditioned matrix (rcond=2.29739e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:200: LinAlgWarning: Ill-conditioned matrix (rcond=3.0474e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# ...

# %%
# - Both curves show a similar pattern overall, but the custom implementation (blue) 
#   starts slightly above the library implementation (green) for smaller lambda values
#   (log10(lambda) between -4 and -2).
# - The MSE slightly decreases as lambda increases (log10(lambda) moves from -4 to around -1),
#   then sharply increases when log10(lambda) > -1.
# - The green line (SL) displays slightly lower MSE in the middle range, indicating 
#   better performance compared to the custom implementation.
# - Both implementations show similar trends. However, the library implementation (green) 
#   performs slightly better in terms of lower MSE within the middle range of lambda values.
# - The sharp MSE increase for larger lambda values aligns with the expected Ridge regression behavior,
#   where too much regularization degrades the model's performance.

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import linear_model

def R2(y_data, y_model):
    return 1 - np.sum((y_data - y_model) ** 2) / np.sum((y_data - np.mean(y_data)) ** 2)
def MSE(y_data,y_model):
    n = np.size(y_model)
    return np.sum((y_data-y_model)**2)/n

np.random.seed(15)

n = 100
x = np.linspace(-3, 3, n)
y = np.exp(-x**2) + 1.5 * np.exp(-(x-2)**2)+ np.random.normal(0, 0.1, x.shape)
p = 5

X = np.zeros((len(x),p))
X[:,0] = 1.0
X[:,1] = x
X[:,2] = x**2
X[:,3] = x**3 
X[:,4] = x**4

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

OLSbeta = np.linalg.inv(X_train.T @ X_train) @ X_train.T @ y_train
print(OLSbeta)
ytildeOLS = X_train @ OLSbeta
print("Training MSE for OLS")
print(MSE(y_train,ytildeOLS))
ypredictOLS = X_test @ OLSbeta
print("Test MSE OLS")
print(MSE(y_test,ypredictOLS))

I = np.eye(p,p)
# lambda value
nlambdas = len(lambdas)

MSEPredict = np.zeros(nlambdas)
MSETrain = np.zeros(nlambdas)
MSEOLSPredict = np.zeros(nlambdas)
MSEOLSTrain = np.zeros(nlambdas)
lambdas = [0.0001,0.001, 0.01,0.1,1.0]
for i in range(nlambdas):
    lmb = lambdas[i]
    Ridgebeta = np.linalg.inv(X_train.T @ X_train+lmb*I) @ X_train.T @ y_train
    # include lasso using Scikit-Learn
    RegOLS = linear_model.LinearRegression()
    RegOLS.fit(X_train,y_train)
    # and then make the prediction
    ytildeRidge = X_train @ Ridgebeta
    ypredictRidge = X_test @ Ridgebeta
    ytildeLasso = RegOLS.predict(X_train)
    ypredictLasso = RegOLS.predict(X_test)
    MSEPredict[i] = MSE(y_test,ypredictRidge)
    MSETrain[i] = MSE(y_train,ytildeRidge)
    MSEOLSPredict[i] = MSE(y_test,ypredictLasso)
    MSEOLSTrain[i] = MSE(y_train,ytildeLasso)

# Now plot the results
plt.figure(figsize= (10,6))
plt.plot(np.log10(lambdas), MSETrain, label = 'MSE Ridge train')
plt.plot(np.log10(lambdas), MSEPredict, 'r--', label = 'MSE Ridge Test')
plt.plot(np.log10(lambdas), MSEOLSTrain, label = 'MSE OLS train')
plt.plot(np.log10(lambdas), MSEOLSPredict, 'r--', label = 'MSE OLS Test')

plt.xlabel('log10(lambda)')
plt.ylabel('MSE')
plt.legend()
plt.show()
# Out:
# [ 0.82150294  0.45123895 -0.02573098 -0.03584182 -0.00360011]
# Training MSE for OLS
# 0.03382271002146029
# Test MSE OLS
# 0.044272279241271105

# %%
# OLS: It has a very low MSE on the training set, which might indicate some overfitting. On the test set, the MSE is slightly higher than on the training set, but still stable.
# Ridge Regression: As expected, Ridge has a larger error than OLS for λ low, both on the training set and the test set. This happens because Ridge includes a penalty that reduces 
# the flexibility of the model, preventing overfitting. However, a λ that is too large can worsen performance by overfitting the model.
